# %%
# !wget http://dati.comune.milano.it/dataset/5c6519f6-6d26-41c9-b53b-6106e08d1b90/resource/533b4e63-3d78-4bb5-aeb4-6c5f648f7f21/download/ds634_civici_coordinategeografiche_20190109.csv
# Out:
# --2019-01-15 19:34:07--  http://dati.comune.milano.it/dataset/5c6519f6-6d26-41c9-b53b-6106e08d1b90/resource/533b4e63-3d78-4bb5-aeb4-6c5f648f7f21/download/ds634_civici_coordinategeografiche_20190109.csv
# Resolving dati.comune.milano.it (dati.comune.milano.it)... 217.31.113.162
# Connecting to dati.comune.milano.it (dati.comune.milano.it)|217.31.113.162|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10113368 (9,6M) [text/csv]
# Saving to: ‘ds634_civici_coordinategeografiche_20190109.csv’
#
# ds634_civici_coordi 100%[===================>]   9,64M  1,73MB/s    in 6,1s
#
# 2019-01-15 19:34:14 (1,59 MB/s) - ‘ds634_civici_coordinategeografiche_20190109.csv’ saved [10113368/10113368]

# %%
# !ls
# Out:
# 533b4e63-3d78-4bb5-aeb4-6c5f648f7f21  Documents  Pictures   Untitled.ipynb
# anaconda3			      Downloads  Public     Videos
# Desktop				      Music	 Templates

# %%
import pandas as pd
import requests

# %%
geo_data = pd.read_csv("ds634_civici_coordinategeografiche_20190109.csv", sep=';')

# %%
geo_data.head()
# Out:
#   NUMERO_CIVICO  CODICE_VIA  CODICE_CIVICO DESCRITTIVO DENOMINAZIONE  \
# 0         17N01           1         196031   DEL DUOMO   DUOMO (DEL)
# 1         15N05           1         195948   DEL DUOMO   DUOMO (DEL)
# 2         15N04           1         195947   DEL DUOMO   DUOMO (DEL)
# 3         15N03           1         195946   DEL DUOMO   DUOMO (DEL)
# 4         15N02           1         195945   DEL DUOMO   DUOMO (DEL)
#
#      STATOCIVICO  RESIDENZIALE  PASSOCARRAIO      GAUSSB_X      GAUSSB_Y  \
# 0  Iter in corso             0           0.0  1514756,6054  5034586,4621
# 1  Iter in corso             0           0.0  1514756,4415  5034581,5103
# 2  Iter in corso             0           0.0  1514756,6399    5034576,14
# 3  Iter in corso             0           0.0  1514756,7471  5034570,0287
# 4  Iter in corso             0           0.0  1514756,8556  5034563,3618
#
#        WGS84_X       WGS84_Y     WEBMERC_X     WEBMERC_Y               LATIT  \
# ...

# %%
tblPrices=pd.read_html("https://www.immobiliare.it/prezzi-mq/Lombardia/Milano.html")

# %%
tblPrices[2]
# Out:
#       CAP  Vendita (€/m²)  Affitto (€/m² al mese)
# 0   20121           7.717                    2374
# 1   20122           7.097                    2193
# 2   20123           6.757                    2060
# 3   20124           5.976                    1908
# 4   20125           3.268                     998
# 5   20126           2.581                     806
# 6   20127           2.538                     800
# 7   20128           2.450                     775
# 8   20129           5.168                    1603
# 9   20131           3.409                    1081
# 10  20132           2.413                     733
# 11  20133           2.658                     808
# 12  20134           2.663                     813
# 13  20135           4.268                    1305
# 14  20136           4.344                    1338
# 15  20137           2.858                     850
# 16  20138           2.438                     750
# 17  20139           2.688                     788
# ...
